# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statistics
# %matplotlib inline
ig = pd.read_csv('/Users/raychilds/Downloads/MFIG3.csv')

# %% [markdown]
# # <center><font color=blue>Top 40 Followed Instagram Influencers of 2018 (& What It Means)</font> </center>

# %% [markdown]
# # <center><font color=blue><font family=georgia>  The Data </center></font color=blue>
# ## <center> I've chosen a dataset provided by Data.World. It contains the top 40 Instagram influencers, their categories, number of followers in millions, age, and nationality, and omits business instagram accounts (Victoria's Secret, Nike, etc), and only omits the personalities. Something to note, these numbers are subject to change at anytime, due to the nature of the social media world (fluctuating followers, especially in times of celebrity drama or promotional materials).
#
# ## <center> The data presents two categories - their general role (celebrity, athlete etc) and then clarifies with the more specific (musician, soccer, etc). Something worth nothing, while these categories are the major role the particular influencer plays, in this millenium it is not uncommon for an influencer to take on many others, for example, modeling, acting, and singing combined.

# %% [markdown]
# # <center><font color=blue> Meet the Influencers</center></font>

# %%
ig.plot(kind='bar', x='brand',y= 'Followers_Millions', title= 'Top 40 Most Followed Instagrammers as of 2018', figsize=(20,15))
plt.ylabel('Followers in Millions')
plt.xlabel('Top 40 Influencers on Instagram')
# Out:
# Text(0.5,0,'Top 40 Influencers on Instagram')

# %%
ig.Followers_Millions.sum()
# Out:
# 2584

# %% [markdown]
# # <center><font color=blue> The sum of their followers is 2,584,000,000 users.</font color=blue></center>
#
# # <center> WHAT?! How could this astronomical number be real? Think about it this way, what are the odds that one user only follows one of these influencers and none of the other? Pretty small. This is the sum total of followers, but, say, you love to watch Taylor Swift and Kim Kardashian's feuding...you'd be counted twice at the very least by these means.</center>
#
#
# # <center><font color=blue> 12.5% of the Top 40 are the Kardashians! All five sisters represented in the Top 20 (25%!)</font color=blue>
#
# # <center><font color=blue> 17.5% of Top 40 originated from the Disney machine...</font color=blue></center>
#
# # <center> So who are they? Let's talk about our Top 8, for all those who were around for the beloved days of MySpace. Think of the remainder of this presentation as their social media profiles.
# 1. Selena Gomez
# 2. Ariana Grande
# 3. Cristiano Ronaldo
# 4. Beyonce
# 5. Taylor Swift
# 6. Kim Kardashian
# 7. Kylie Jenner
# 8. Dwayne "The Rock" Johnson
# </center>
#
# # <center> Sound familiar? If they don't, I suggest you peer out of the rock you're living under! Let's dive deeper into who these "most watched" people are.</center></font color=pink>

# %% [markdown]
# # <center><font color=blue> Gender of Influencers</center></font color=blue>

# %%
labels = 'Female', 'Male'
sizes = [55, 45]
explode = (0.1, 0)      
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 
print("Gender of Top 40 Most Followed Instagram Influencers")
plt.show()
# Out:
# Gender of Top 40 Most Followed Instagram Influencers

# %% [markdown]
# ## <center> Females make up 10% more of the Top 40 than males.

# %% [markdown]
# # <center><font color=blue> Average Ages of Influencers</center></font color=blue>

# %% [markdown]
# ## <center> Let's zero in on the demographics of our social media superstars.

# %%
ig = pd.read_csv('/Users/raychilds/Downloads/MFIG2.csv')
ig.describe()
# Out:
#        Followers (Millions)        Age
# count             41.000000  41.000000
# mean              63.024390  32.024390
# std               30.096917   7.329692
# min               20.000000  21.000000
# 25%               38.000000  26.000000
# 50%               60.000000  31.000000
# 75%               79.000000  37.000000
# max              130.000000  51.000000

# %%
statistics.mode(ig['Age'])
# Out:
# 26

# %% [markdown]
# ## <center> The average age of the Top 40 Instagram Influencers as of 2018 is 32 years old, with ages ranging from 21 and 51 years old, a 30 year difference. The most occuring age in the Top 40 influencers is 26 years old.

# %%
ig.plot(kind='scatter', x='Age',y= 'Followers_Millions', figsize=(10,5), title= 'Age and Number of Followers in the Top 40 Most Followed Instagrammers of 2018',)

# %% [markdown]
# ## <center> There doesn't seem to be much correlation between age and numbers of followers; we can conclude the audiences of these influencers are loyal despite age. A beloved celebrity is a beloved celebrity. </center>

# %%
ig.plot(kind='hist', x='brand',y= 'Age', figsize=(20,15))

# %% [markdown]
# ## <center> Our outliers, unsurprisingly perhaps, hit no older than 51 years of age. Who is that? Mr. Vin Diesel. The next influencer closest in age is The Rock, who holds a place in our Top 8. David Beckham to follow. The oldest females in the crew are Kim Kardashian and her sister Kourtney, both in the Top 20.
#
# ## <center> The youngest influencer is 21 years old, Ms. Kyle Jenner (half-sibling of the Kardashians), who holds the 7th spot in most followed, just one spot behind her sister Kim.

# %%
x = ig['Age']
plt.title('Ages of Top 40 Most Followed Instagram Influencers (2018)')
plt.ylabel('Ages (Years)')
plt.boxplot(x)
plt.show()

# %% [markdown]
# ## <center> This little boxplot does a great job showing us 75% of the Top 40 Instagrammers are below the age of 35 years old, 50% 30 or below.

# %% [markdown]
# # <center><font color=blue> Nationality of Influencers </center></font color=blue>

# %%
labels = 'American', 'Brazillian', 'Porteguese' , 'Spanish', 'Barbadian', 'English', 'China', 'Swedish','Colombian'
sizes = [27, 2, 3, 1, 1, 3, 1, 1, 2]    
fig1, ax1 = plt.subplots()
explode = (0, 0, 0, 0, 0, 0, 0, 0, 0,)
ax1.pie(sizes,labels=labels, explode=explode, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 
plt.title("Nationality Breakdwon of Top 40 Instagram Influencers")
plt.show()

# %% [markdown]
# ## <center> Nationality, like professions, is another difficult greyscale topic. For example, Nicki Minaj is Trinidadian, but she spent most of her childhood and life in New York City. Also, most of the influencers now live in the United States and have citizenship, but they are counted here as their birth of origin.
#
# ## <center> Americans make up about 66% of the Top 40 Most Followed. The Latino community is not far behind, with almost 20% of the makeup, 10% out of Brazil and Colombia. Keep this in mind as we explore professions below.

# %% [markdown]
# # <center><font color=blue> Profession of Influencers</center></font color=blue>

# %%
labels = 'Musician', 'Actor', 'Soccer' , 'Comedian', 'Beauty', 'Football', 'Basketball', 'Reality','Social'
sizes = [18, 5, 6, 1, 2, 1, 1, 5, 1]   
fig1, ax1 = plt.subplots()
explode = (0, 0, 0, 0, 0, 0, 0, 0, 0,)
ax1.pie(sizes,labels=labels, explode=explode, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 
plt.title("Industry of Top 40 Instagram Influencers")
# Out:
# Text(0.5,1,'Industry of Top 40 Instagram Influencers')

# %% [markdown]
# ## <center> Be sure not to neglect the littliest slices of the pie. They are not random, they are what the data represents. So, even though, say, football is only 2.5% of the overall influencers, they still made the cut! For example, baseball is nowhere to be seen. Remember our figure from earlier - 12.5% is composed of all five of the Kardashian sister. No other influencer makes up this stat. So, this means, 100% of the Reality Celebrity profession is from one single family.
#
# ## <center> Soccer by itself deserves it's own explanation. 15% of the Top 40 Most Followed Instagram Influencers were soccer players! These players are the majority of the Latino community we just checked out, saving for Maluma and Shakira, who are musicians.
#
#
# #### <center> *Remember, most of these influencers play multiple roles in the world. Think about musicians, for example. Back some 40 years ago, money came predominantly from beloved albums. With the genesis of the internet, however; it feels like the entire Age of Technology has been spent fighting pirating. Napster, Limewire... Lo and behold the world started to stream with Pandora and Spotify. Some on Apple music, etc. Pirating was sharply cut back, but not without a trade-off, to say the least. Revenue was cut greatly, so what's a musician to do? As a musician in the 21st century, you have to be a jack of all trades. Model, actress, instagrammer, clothing lines, perfume, makeup...you name it.

# %% [markdown]
# # <center><font color=blue> Further Exploration </center></font color=blue>

# %% [markdown]
# ## <center> It is no secret the United States of America plays a huge cultural role in the world, with hotly debated topics including exceptionalism, capitalism, and cultural imperialism. While exploring the data, I struggled to categorize the influencers in terms of black and white, for example, American vs. Barbadian. Is Rihanna an American influencer as she now works and lives in the United States as this is where the industry is? Can we count her as a Barbadian influencer? If ethnicity had been brought into the puzzle, perhaps all of this data could be considered skewed. To be "American" even, is a very difficult topic. What is American? Is it citizenship? It is in this particular data that we see how important the multicultural melting pot is to the American world.
#
# ## <center> Something else that occurred to me as I explored this dataset: race. Continuing on my piece above on ethnicity and nationality and "Americanism"...how much of the influencers identify as African American or mixed race? And, perhaps more importantly, how has this changed over the years? We are burdened with the limited timeline of social media, Instagram only being around for 10 years! Perhaps other means could be used to account for the top influencers of the 20th century, and how they compare to now. It will also be interesting to continue to watch the cultural infusion as the years go by.
#
# ## <center> I'd also like to do a study on the values of these influencers. I'd draw on other social media applications including YouTube, Snapchat, Facebook, etc. The ages of these particular influencers struck me, what does it mean that 75% of the most followed are under the age of 30 years old? How does this impact the rest of the world? An entire study could be on the Kardashians and their cultural influence, by themselves. Disney is another piece of our puzzle that could have it's own slew of information explored in it's role on global culture. If we add back in the accounts that were ommited, Nike, Nike Football, and Victoria's Secret, the values that Beauty and Soccer play in the world increase. What exactly does this mean and why? One last question on this particular food for thought, who are the demographics of this paricular app, and how are we shaping them in this increasingly digital age?
