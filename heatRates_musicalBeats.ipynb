# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import statistics
# %matplotlib inline

hr = pd.read_csv('/Users/raychilds/Desktop/ThinkfulFiles/hr.csv')
spt = pd.read_csv('/Users/raychilds/Downloads/Spotify2k17.csv')

# %% [markdown]
# # Heart Rates in Pop Music: An Analysis.
#
# The biological reason for human being's affection toward music is a [hotly researched topic](http://www.pbs.org/wgbh/nova/blogs/secretlife/blogposts/the-evolution-of-music/). There is much work done on whether our biological rhythm in the autonomomic nervous system (heart rate) is correlated with musical tempos (both are measured in beats per minute (BPM). For this analysis, we will assume that it is, establish a baseline resting heart rate for the average person, and then see where the median and mode BPM's fall within Spotify's Top 100 Music Hit List from 2017.
#
# I've chosen a simple dataset of 130 patients resting heart rates from the American Heart Association ordered simply by anonymous patient number, and their results from a heart monitor, while no activity was being performed. It's important to note, these rates may or may not be slightly higher than rest, if for some reason the patient was nervous while in the doctor's office, something they may percieve as "unnatural", thus a higher heartbeat.
#
# The second dataset is Spotify's Top 100 Songs from 2017, categorizing the music by acousticness, energy, beats per minute, etc. Spotify is currently the leading music streaming servince in the world, and providing a public API by artist, song, and charts.

# %% [markdown]
# # 1) What is the Average Resting Heart Rate in BPM?

# %%
hr.hist('HeartRate')
plt.xlabel('Heart Rates Per Minute')
plt.title('Average Heart Rates in 130 Patients')
plt.xlim(55,90)
plt.show()

# %%
(values, counts) = np.unique(hr['HeartRate'], return_counts=True)
ind = np.argmax(counts)
values[ind]
# Out:
# 73

# %%
hr.describe()
# Out:
#          Patients   HeartRate
# count  130.000000  130.000000
# mean    65.500000   73.761538
# std     37.671829    7.062077
# min      1.000000   57.000000
# 25%     33.250000   69.000000
# 50%     65.500000   74.000000
# 75%     97.750000   79.000000
# max    130.000000   89.000000

# %% [markdown]
# The average heartrate of a person at rest is 73 heart beats per minute. Resting heartrates are typically measured using bell curves, as they are a naturally occurring biological phenomenon with few outliers.

# %% [markdown]
# # 2)  Is There a Preferred Tempo* in Top 100 Music? Where does this Number Lie in Relation to the Average Resting Heart Rate?

# %% [markdown]
# *Tempo (noun) : Speed at which music is played, measured in BPM

# %% [markdown]
# Let's search the entire top 100 list for songs with the same amount of beats per minute as the average resting person:

# %%
spt.loc[lambda df: spt['tempo'] > 73, :]
# Out:
#                        id                                               name  \
# 0   7qiZfU4dY1lWllzX7mPBI                                       Shape of You
# 1   5CtI0qwDJkDQGwXD1H1cL                                  Despacito - Remix
# 2   4aWmUDTfIPGksMNLV2rQP                 Despacito (Featuring Daddy Yankee)
# 3   6RUKPb4LETWmmr3iAEQkt                           Something Just Like This
# 4   3DXncPQOG4VBw3QHh3S81                                        I'm the One
# 5   7KXjTSCq5nL1LoYtL7XAw                                            HUMBLE.
# 6   3eR23VReFzcdmS7TYCrhC                    It Ain't Me (with Selena Gomez)
# 7   3B54sVLJ402zGa6Xm4YGN                                      Unforgettable
# 8   0KKkJNfGyhkQ5aFogxQAP                                 That's What I Like
# 9   3NdDpSvN911VPGivFlV5d  I Don’t Wanna Live Forever (Fifty Shades Darke...
# 10  7GX5flRQZVHRAGd6B4TmD                                      XO TOUR Llif3
# ...

# %%
df0 = spt.loc[lambda df: spt['tempo'] > 73, :]
len(df0)
# Out:
# 100

# %% [markdown]
# ### 100% of the songs on the Top 100 List has a tempo above the average resting heart rate; now that we've established an orientation, let's keep this in mind and try going higher:

# %%
spt.loc[lambda df: spt['tempo'] > 130, :]
# Out:
#                        id                                name  \
# 2   4aWmUDTfIPGksMNLV2rQP  Despacito (Featuring Daddy Yankee)
# 5   7KXjTSCq5nL1LoYtL7XAw                             HUMBLE.
# 8   0KKkJNfGyhkQ5aFogxQAP                  That's What I Like
# 10  7GX5flRQZVHRAGd6B4TmD                       XO TOUR Llif3
# 14  0VgkVdmE4gld66l8iyGjg                            Mask Off
# 17  6PCUP3dWmTjcTtXY02oFd                  Castle on the Hill
# 21  0tKcYR2II1VCQWT79i5Nr                             Thunder
# 27  3ebXMykcMXOcLeJ9xZ17X                 Scared to Be Lonely
# 31  5aAx2yezTd8zXrkmtKl66                             Starboy
# 37  7wGoVu4Dady5GV0Sv4UIs                            rockstar
# 39  3A7qX2QjDlPnazUsRk5y0            2U (feat. Justin Bieber)
# 51  343YBumqHu19cGoGARUTs                           Fake Love
# 52  4pdPtRcBmOSQDlJ3Fk945                     Let Me Love You
# 57  3m660poUr1chesgkkjQM7                     Sorry Not Sorry
# ...

# %%
df1 = spt.loc[lambda df: spt['tempo'] > 130, :]

# %%
len(df1)
# Out:
# 31

# %% [markdown]
# ### 31% of the songs in the top 100 have a BPM of 130 or higher.

# %%
spt.loc[lambda df: spt['tempo'] > 140, :]
# Out:
#                        id                                name  \
# 2   4aWmUDTfIPGksMNLV2rQP  Despacito (Featuring Daddy Yankee)
# 5   7KXjTSCq5nL1LoYtL7XAw                             HUMBLE.
# 10  7GX5flRQZVHRAGd6B4TmD                       XO TOUR Llif3
# 14  0VgkVdmE4gld66l8iyGjg                            Mask Off
# 21  0tKcYR2II1VCQWT79i5Nr                             Thunder
# 31  5aAx2yezTd8zXrkmtKl66                             Starboy
# 37  7wGoVu4Dady5GV0Sv4UIs                            rockstar
# 39  3A7qX2QjDlPnazUsRk5y0            2U (feat. Justin Bieber)
# 52  4pdPtRcBmOSQDlJ3Fk945                     Let Me Love You
# 57  3m660poUr1chesgkkjQM7                     Sorry Not Sorry
# 58  3kxfsdsCpFgN412fpnW85                             Redbone
# 61  3umS4y3uQDkqekNjVpiRU                           El Amante
# 63  6520aj0B4FSKGVuKNsOCO               Chained To The Rhythm
# 66  5hYTyyh2odQKphUbMqc5g      How Far I'll Go - From "Moana"
# ...

# %%
df2 = spt.loc[lambda df: spt['tempo'] > 140, :]

# %%
len(df2)
# Out:
# 20

# %% [markdown]
# ### 20% of the songs in the top 100 have a BPM of 140 or higher.

# %%
spt.loc[lambda df: spt['tempo'] > 150, :]
# Out:
#                        id                                name  \
# 2   4aWmUDTfIPGksMNLV2rQP  Despacito (Featuring Daddy Yankee)
# 5   7KXjTSCq5nL1LoYtL7XAw                             HUMBLE.
# 10  7GX5flRQZVHRAGd6B4TmD                       XO TOUR Llif3
# 14  0VgkVdmE4gld66l8iyGjg                            Mask Off
# 21  0tKcYR2II1VCQWT79i5Nr                             Thunder
# 31  5aAx2yezTd8zXrkmtKl66                             Starboy
# 37  7wGoVu4Dady5GV0Sv4UIs                            rockstar
# 52  4pdPtRcBmOSQDlJ3Fk945                     Let Me Love You
# 58  3kxfsdsCpFgN412fpnW85                             Redbone
# 61  3umS4y3uQDkqekNjVpiRU                           El Amante
# 63  6520aj0B4FSKGVuKNsOCO               Chained To The Rhythm
# 66  5hYTyyh2odQKphUbMqc5g      How Far I'll Go - From "Moana"
# 83  4pLwZjInHj3SimIyN9SnO                        Side To Side
# 96  0QsvXIfqM0zZoerQfsI9l                   Don't Let Me Down
# ...

# %%
df3 = spt.loc[lambda df: spt['tempo'] > 150, :]

# %%
len(df3)
# Out:
# 15

# %% [markdown]
# ### 7% of the songs in the top 100 have a BPM of 150 or higher.

# %%
spt.loc[lambda df: spt['tempo'] > 160, :]
# Out:
#                        id                                name  \
# 2   4aWmUDTfIPGksMNLV2rQP  Despacito (Featuring Daddy Yankee)
# 21  0tKcYR2II1VCQWT79i5Nr                             Thunder
# 31  5aAx2yezTd8zXrkmtKl66                             Starboy
# 52  4pdPtRcBmOSQDlJ3Fk945                     Let Me Love You
# 58  3kxfsdsCpFgN412fpnW85                             Redbone
# 61  3umS4y3uQDkqekNjVpiRU                           El Amante
# 63  6520aj0B4FSKGVuKNsOCO               Chained To The Rhythm
# 66  5hYTyyh2odQKphUbMqc5g      How Far I'll Go - From "Moana"
# 99  1j4kHkkpqZRBwE0A4CN4Y         Dusk Till Dawn - Radio Edit
#
#              artists  danceability  energy   key  loudness  mode  speechiness  \
# 2         Luis Fonsi         0.660   0.786   2.0    -4.757   1.0       0.1700
# 21   Imagine Dragons         0.600   0.810   0.0    -4.749   1.0       0.0479
# 31        The Weeknd         0.681   0.594   7.0    -7.028   1.0       0.2820
# ...

# %%
df4 = spt.loc[lambda df: spt['tempo'] > 160, :]
len(df4)
# Out:
# 9

# %% [markdown]
# ### 9% of the songs in the top 100 have a BPM of 160 or higher.

# %%
spt.loc[lambda df: spt['tempo'] > 170, :]
# Out:
#                        id                                name       artists  \
# 2   4aWmUDTfIPGksMNLV2rQP  Despacito (Featuring Daddy Yankee)    Luis Fonsi
# 31  5aAx2yezTd8zXrkmtKl66                             Starboy    The Weeknd
# 52  4pdPtRcBmOSQDlJ3Fk945                     Let Me Love You      DJ Snake
# 61  3umS4y3uQDkqekNjVpiRU                           El Amante     Nicky Jam
# 63  6520aj0B4FSKGVuKNsOCO               Chained To The Rhythm    Katy Perry
# 66  5hYTyyh2odQKphUbMqc5g      How Far I'll Go - From "Moana"  Alessia Cara
# 99  1j4kHkkpqZRBwE0A4CN4Y         Dusk Till Dawn - Radio Edit          ZAYN
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 2          0.660   0.786   2.0    -4.757   1.0       0.1700        0.2090
# 31         0.681   0.594   7.0    -7.028   1.0       0.2820        0.1650
# 52         0.476   0.718   8.0    -5.309   1.0       0.0576        0.0784
# ...

# %%
df5 = spt.loc[lambda df: spt['tempo'] > 170, :]

# %%
len(df5)
# Out:
# 7

# %% [markdown]
# ### 7% of the songs in the top 100 have a BPM of 170 or higher.

# %%
spt.loc[lambda df: spt['tempo'] > 180, :]
# Out:
#                        id                         name     artists  \
# 31  5aAx2yezTd8zXrkmtKl66                      Starboy  The Weeknd
# 52  4pdPtRcBmOSQDlJ3Fk945              Let Me Love You    DJ Snake
# 63  6520aj0B4FSKGVuKNsOCO        Chained To The Rhythm  Katy Perry
# 99  1j4kHkkpqZRBwE0A4CN4Y  Dusk Till Dawn - Radio Edit        ZAYN
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 31         0.681   0.594   7.0    -7.028   1.0       0.2820        0.1650
# 52         0.476   0.718   8.0    -5.309   1.0       0.0576        0.0784
# 63         0.448   0.801   0.0    -5.363   1.0       0.1650        0.0733
# 99         0.258   0.437  11.0    -6.593   0.0       0.0390        0.1010
#
#     instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 31          0.000003     0.134   0.5350  186.054     230453.0             4.0
# 52          0.000010     0.122   0.1420  199.864     205947.0             4.0
# ...

# %%
df6 = spt.loc[lambda df: spt['tempo'] > 180, :]
len(df6)
# Out:
# 4

# %% [markdown]
# ### 4% of the songs in the top 100 have a BPM of 180 or higher.

# %%
spt.loc[lambda df: spt['tempo'] > 190, :]
# Out:
#                        id             name   artists  danceability  energy  \
# 52  4pdPtRcBmOSQDlJ3Fk945  Let Me Love You  DJ Snake         0.476   0.718
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 52  8.0    -5.309   1.0       0.0576        0.0784           0.00001
#
#     liveness  valence    tempo  duration_ms  time_signature
# 52     0.122    0.142  199.864     205947.0             4.0

# %%
df7 = spt.loc[lambda df: spt['tempo'] > 190, :]
len(df7)
# Out:
# 1

# %% [markdown]
# ### 1% of the songs in the top 100 have a BPM of 190 or higher.

# %%
labels = '130 BPM', '140 BPM', '150 BPM', '160 BPM', '170 BPM', '180 BPM', '190 BPM'
sizes = [31, 20, 15, 9, 7, 4, 1]
explode = (0, 0, 0, 0, 0, 0, 0.5)      
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 
print("Beats Per Minute in Top 100 Music (Spotify 2017)")
plt.show()
# Out:
# Beats Per Minute in Top 100 Music (Spotify 2017)

# %%
x = [75, 130, 140, 150, 160, 170, 180, 190]
y = [100, 31, 20, 15, 9, 7, 4, 1]
plt.ylabel('Beats Per Minute')
plt.xlim(10, 210)
plt.ylim(0,105)
plt.title('Beats Per Minute in Top 100 Music (Spotify 2017)')
plt.scatter(x,y)

plt.show()

# %% [markdown]
# ## If there is indeed a connection between our autonomic nervous system and musical tempo, it would appear that we choose beats far above our own resting heart. Let's look at the Top 10 for the range of most preferred BPM's:

# %% [markdown]
# # 3) What Are the BPM's in the Biggest Hits (Top 10% of Spotify's 2017 Chart) ?

# %%
spt[0 : 10]['tempo'].plot()
plt.title('Beats Per Minute in the Top 10 Songs of 2017')
plt.xlim(0,9)
plt.ylabel('Beats Per Minute')
plt.xlabel('Top 10 Songs in 2017')
# Out:
# Text(0.5,0,'Top 10 Songs in 2017')

# %%
spt[0:10]['tempo'].describe()
# Out:
# count     10.000000
# mean     114.669600
# std       30.563781
# min       80.924000
# 25%       96.479000
# 50%      101.493500
# 75%      130.042750
# max      177.833000
# Name: tempo, dtype: float64

# %%
x = spt[0:10]['tempo']
plt.title('Tempo in Top 10 Songs from Spotify 2017')
plt.ylabel('Beats Per Minute')
plt.boxplot(x)
plt.show()

# %%
(values, counts) = np.unique(spt[0:10]['tempo'], return_counts=True)
ind = np.argmax(counts)
values[ind]
# Out:
# 80.92399999999999

# %% [markdown]
# ### In the Top 10 of Spotify's Chart from 2017, the average tempo was 114 Beats Per Minute, 41 Beats above the average resting heart rate. However, the tempo most frequently found in the Top 10 was 80 Beats Per Minute, only 7 BPM's above a resting a heart rate. Also, remember that all 100 songs in the list were over the average person's resting heart rate.
#
# ### So, if we do indeed enjoy music due to it's correlation with our biological rhythms, and if pop music is a decent meausre of the most listened to music due to it's deliberate commercialized nature, perhaps we do enjoy most tempos above our normal activity levels, music that gets our hearts pounding and circulations revved, music that makes us dance.

# %% [markdown]
# # Further Research

# %% [markdown]
# It'd be fascinating to take a look at musical genres and the numerical conventions that define them, for example, what are the Beats Per Minute in each genre, and why is this so?
#
# I would love to link this somehow as well to the psychology of songwriters and producers, and analyze why a certain personality type would end up producing in whatever genre they're most drawn to. I'd also like to link traits of creative types to the music they producer (Did Johnny Cash write his music in moments when he had a lower than average BPM? What are the reasons for the "mournful" qualities of his music?) How can we connect moods to chords? Do people with certain genetic predispositions fall into a certain range of chords? Who is the kind of person that goes toward Major Chords? Minor Chords? 7th Chords?
#
# I suppose to go about this I'd choose the specialization of Social Science. I would need to learn how to reduce words down to their most specific, logical forms so I could define them well enough in order to compose a numerical analysis of them. For example, how do I measure "mournfulness"?
