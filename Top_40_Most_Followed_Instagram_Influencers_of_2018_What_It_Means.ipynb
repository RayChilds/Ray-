# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statistics
# %matplotlib inline
ig = pd.read_csv('/Users/raychilds/Downloads/MFIG4.csv')

# %% [markdown]
# # <center><font color=blue>Top 40 Followed Instagram Influencers of 2018 (& What It Means)</font> </center>

# %% [markdown]
# ## <center><font color=blue><font family=georgia>  The Data </center></font color=blue>
# ## <center> I've chosen a dataset provided by Data.World. It contains the top 40 Instagram influencers, their categories both general and specific, number of followers in millions, age, and nationality. The dataset omits business instagram accounts (Victoria's Secret, Nike, etc), and only explores the personalities. Something to note, these numbers themselves are subject to change at anytime, due to the nature of the social media world (fluctuating followers, especially in times of celebrity drama/promotion), but this would not necessarily change the influencers themselves, for reasons we'll explore below.

# %% [markdown]
# # <center><font color=blue> Meet the Influencers:</center></font color=blue>
# # <center><font color=blue> 1) Are There Any Major Patterns in the Top 40?</center></font color=blue>

# %%
ig.plot(kind='bar', x='brand',y= 'Followers_Millions', title= 'Top 40 Most Followed Instagrammers as of 2018', figsize=(20,15))
plt.ylabel('Followers in Millions')
plt.xlabel('Top 40 Influencers on Instagram')
# Out:
# Text(0.5,0,'Top 40 Influencers on Instagram')

# %% [markdown]
# # <center> Here's a snapshot of our Top 8, for those of us who were around for MySpace.
# 1. Selena Gomez
# 2. Ariana Grande
# 3. Cristiano Ronaldo
# 4. Beyonce
# 5. Taylor Swift
# 6. Kim Kardashian
# 7. Kylie Jenner
# 8. Dwayne "The Rock" Johnson
# </center>
#
# ## <center> Ever heard of them? </center>

# %% [markdown]
# ## <center> When we take a closer look, 12.5% of the Top 40 are the Kardashians! All five sisters represented in the Top 20 (a whopping 25%). It's interesting to note that until recently, the three Kardashian girls were on their own. Now teenagers, their half-sisters Kylie and Kendall have joined the ranks. So much so that Ms. Jenner is one below Kim in the Instagram-following-race, surpassing all the rest of the family. She is also the youngest of all the influencers on the list.
#
# ## <center> 17.5% of the Top 40 got their major breaks within the Walt Disney Company: Selena Gomez, Ariana Grande, Vanessa Hudgens, Zac Efron, Demi Lovato, and Miley Cyrus. It begs to question their algorithm for massive fame.</center>
#
# ## <center> Upon closer examination (but not too close!), it occurred to me that three figureheads in the Top Followed have had sexual content of theirs posted publically: Kim Kardashian, Justin Bieber, and Vanessa Hudgens. Vanessa Hudgens is an interesting person to be on the Top 40 list, as she is arguably the least "famous", it makes me wonder if the nude leaks, in the end, helped peak/peek interest in her.
#
# ## <center> On that note, I'm inspired to look again, this time real, real close. There is exactly one (natural) blonde on our 'grammers list! Taylor, that's all you, girl!

# %% [markdown]
# # <center><font color=blue> 2) Demographics of Influences: Are Instagram Audiences One Type of Person Over Another? </center></font color=blue>

# %%
labels = 'Female', 'Male'
sizes = [55, 45]
explode = (0.1, 0)      
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 
print("Gender of Top 40 Most Followed Instagram Influencers")
plt.show()
# Out:
# Gender of Top 40 Most Followed Instagram Influencers

# %% [markdown]
# ## <center> Females make up 10% more of the Top 40 than males.

# %%
ig = pd.read_csv('/Users/raychilds/Downloads/MFIG2.csv')
ig.describe()
# Out:
#        Followers (Millions)        Age
# count             41.000000  41.000000
# mean              63.024390  32.024390
# std               30.096917   7.329692
# min               20.000000  21.000000
# 25%               38.000000  26.000000
# 50%               60.000000  31.000000
# 75%               79.000000  37.000000
# max              130.000000  51.000000

# %%
statistics.mode(ig['Age'])
# Out:
# 26

# %%
ig.plot(kind='hist', x='brand',y= 'Age', figsize=(20,15))

# %% [markdown]
# ## <center> The average age of the Top 40 Instagram Influencers is 32 years old, with an age range of 21 to 51 years old - a 30 year difference. The most occuring age in the Top 40 influencers is 26 years old (5 influencers). For generational orientation, our modes were born in 1992. Hashtag Milennials.
#
# ## <center> Our outliers, unsurprisingly perhaps, hit no older than 51 years of age. Who is that? Mr. Vin Diesel. The next influencer closest in age is The Rock, who holds a place in our Top 8. David Beckham to follow. The oldest females in the crew are Kim Kardashian and her sister Kourtney, both in the Top 20.
#
# ## <center> The youngest influencer is 21 years old, Ms. Kyle Jenner (half-sibling of the Kardashians), who holds the 7th spot in most followed, just one spot behind her sister Kim.
#
# ## <center> This is quite a range of ages, could it be that certain ages have any more or less followers than the others in the list? Let's check it out:

# %%
ig.plot(kind='scatter', x='Age',y= 'Followers_Millions', figsize=(10,5), title= 'Age and Number of Followers in the Top 40 Most Followed Instagrammers of 2018',)

# %%
x = ig['Age']
plt.title('Ages of Top 40 Most Followed Instagram Influencers (2018)')
plt.ylabel('Ages (Years)')
plt.boxplot(x)
plt.show()

# %% [markdown]
# ## <center> There doesn't seem to be much too much correlation, with only slight action of average followers in the 20 something to 30 year old range. Age does not dictate the number of followers a typical instagrammer has, although this is within our original range (75% of our Instagrammers are younger than 35 years old, and 50% in the 30 or below.) It may if we explored data of younger and older than our outliers of 21 and 51. It'd be interesting to see how this dataset changes in the next 20 - 30 years, will top influencers stay in these age ranges, replacing the current social medialites, or will they follow them throughout the years?
# </center>
#
# ## <center> So, now that we've established from when they're from, how about from whence?

# %%
labels = 'American', 'Brazillian', 'Porteguese' , 'Spanish', 'Barbadian', 'English', 'Chinese', 'Swedish','Colombian', 'Canadian'
sizes = [26, 2, 3, 1, 1, 3, 1, 1, 2, 1]    
fig1, ax1 = plt.subplots()
explode = (0, 0, 0, 0, 0, 0, 0.3, 0.4, 0, 0.1)
ax1.pie(sizes,labels=labels, explode=explode, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 
plt.title("Nationality Breakdwon of Top 40 Instagram Influencers")
plt.show()

# %% [markdown]
# ## <center> Nationality is a difficult greyscale topic. For example, Nicki Minaj is Trinidadian, but she spent most of her childhood and life in New York City. Also, most of the influencers now live in the United States and have citizenship, but they are counted here as their country of origin.
#
# ## <center> Americans make up 63.4% of the Top 40 Most Followed. The Latino community is not far behind, with almost 20% of the makeup, 10% out of Brazil and Colombia. Keep this in mind as we explore professions below. If you are a Top 40 pop music listener, this may not come as too much of a surprise for you. There is an uptick in blending hip hop, electronic, and most recently the Latino music industries.

# %% [markdown]
# # <center><font color=blue> 3) What Cultural Values are Represented in the Data? </center></font color=blue>

# %%
labels = 'Musician', 'Actor', 'Soccer' , 'Comedian', 'Beauty', 'Football', 'Basketball', 'Reality','Social'
sizes = [18, 5, 6, 1, 2, 1, 1, 5, 1]   
fig1, ax1 = plt.subplots()
explode = (0, 0, 0, 0, 0, 0, 0, 0, 0,)
ax1.pie(sizes,labels=labels, explode=explode, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 
plt.title("Industry of Top 40 Instagram Influencers")
# Out:
# Text(0.5,1,'Industry of Top 40 Instagram Influencers')

# %% [markdown]
# ## <center> Be sure not to neglect the littliest slices of the pie. They are not random, they are what the data represents. So, even though, say, football is only 2.5% of the overall influencers, they still made the cut! For example, baseball is nowhere to be seen. Remember our figure from earlier - 12.5% of the entire set is composed of all five of the Kardashian sisters. No other influencer makes up this stat; this means 100% of the Reality Celebrity profession is from one single family!
#
# ## <center> Soccer by itself deserves it's own blurb. 15% of the Top 40 Most Followed Instagram Influencers were soccer players! These players are the majority of the Latino community we just checked out, saving for Maluma and Shakira, who are musicians.
#
# ## <center> Remember, most of these influencers play multiple roles in the world. Think about musicians, for example. Back some 40 years ago, money came predominantly from beloved albums. With the genesis of the internet, however; it feels like the entire Age of Technology has been spent fighting pirating. Napster, Limewire... Lo and behold the world started to stream with Pandora and Spotify. Some on Apple music, etc. Pirating was sharply cut back, but not without a trade-off, to say the least. Revenue was cut greatly, so what's a musician to do? As a musician in the 21st century, you have to be a jack of all trades. Model, actress, instagrammer, clothing lines, perfume, makeup...you name it. So, let's try to imagine what that looks like. Combine beauty, musicians, actors, reality, and social and let's see what we get:

# %%
labels = 'Influencer Brand', 'Comedy', 'Sports'
sizes = [77.5, 2.5, 20]
explode = (0.1, 0, 0)      
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%')
ax1.axis('equal') 
print("Influencer Brands vs. Sports in the Top 40")
plt.show()
# Out:
# Influencer Brands vs. Sports in the Top 40

# %% [markdown]
# ## <center> CHECK THAT OUT! Don't forget though, David Beckham could also be included in our Beauty category! I've chosen for simplicity's sake to leave him and his football be, for now.
#
# ## <center> It seems to me if you have certain qualities, a perfect storm of looks and a capacity to appeal to the masses (or hire someone to do so), you're well on your way to owning over three-quarters of the Instagram empire. Something we haven't covered here? Moo-la. Here's a factoid to blow your socks off. Ms. Kylie Jenner (our youngest instagrammer) makes one million dollars PER paid instragram post. It pays to post, ladies and gentlemen.

# %% [markdown]
# # <center><font color=blue> Further Exploration </center></font color=blue>

# %% [markdown]
# ## <center> It is no secret the United States of America plays a huge cultural role in the world, with hotly debated topics including exceptionalism, capitalism, and cultural imperialism. While exploring the data, I struggled to categorize the influencers in terms of black and white, for example, American vs. Barbadian. Is Rihanna an American influencer as she now works and lives in the United States as this is where the industry is? Can we count her as a Barbadian influencer? If ethnicity had been brought into the puzzle, perhaps all of this data could be considered skewed. To be "American" even, is a very difficult topic. What is American? Is it citizenship? It is in this particular data that we see how important the multicultural melting pot is to the American world.
#
# ## <center> Something else that occurred to me as I explored this dataset: race. Continuing on my piece above on ethnicity and nationality and "Americanism"...how much of the influencers identify as African American or mixed race? And, perhaps more importantly, how has this changed over the years? We are burdened with the limited timeline of social media, Instagram only being around for 10 years! Perhaps other means could be used to account for the top influencers of the 20th century, and how they compare to now. It will also be interesting to continue to watch the cultural infusion as the years go by.
#
# ## <center> I'd also like to do a study on the values of these influencers. I'd draw on other social media applications including YouTube, Snapchat, Facebook, etc. The ages of these particular influencers struck me, what does it mean that 75% of the most followed are under the age of 30 years old? How does this impact the rest of the world? An entire study could be on the Kardashians and their cultural influence, by themselves. Disney is another piece of our puzzle that could have it's own slew of information explored in it's role on global culture. If we add back in the accounts that were ommited, Nike, Nike Football, and Victoria's Secret, the values that Beauty and Soccer play in the world increase. What exactly does this mean and why? One last question on this particular food for thought, who are the demographics of this paricular app, and how are we shaping them in this increasingly digital age?

# %% [markdown]
# ### <center><font color=pink>*Fun Fact: The sum of their followers is 2,584,682,964 users.*</center></font color=pink>
# ### <center><font color=pink> WHAT?! How could this astronomical number be real? Think about it this way, what are the odds that one user only follows one of these influencers and none of the other? Pretty small. This is the sum total of followers, but, say, you love to watch Taylor Swift and Kim Kardashian's feuding...you'd be counted twice at the very least by these means.</center></font color=pink>
